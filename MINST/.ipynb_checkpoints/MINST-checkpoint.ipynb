# %% [markdown]
# # 1. Loading data

# %%
import pandas as pd
from sklearn.cross_validation import cross_val_score
import numpy as np
import matplotlib.pyplot as p
train_images = pd.read_csv("./train.csv")
test_images = pd.read_csv("./test.csv")

train_images_numpy = train_images[train_images.columns[1:]].as_matrix()

# %% [markdown]
# # 2. Visualization

# %% [markdown]
# ## 2.1 Visualization 1s and 8s using PCA

# %%
from  sklearn.decomposition import PCA
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.pyplot as plt

ones = train_images[train_images['label']==1]
ones_numpy = ones[train_images.columns[1:]].as_matrix()

#fours = train_images[train_images['label']==4]
#fours_numpy = ones[train_images.columns[1:]].as_matrix()

eights = train_images[train_images['label']==8]
eights_numpy = eights[train_images.columns[1:]].as_matrix()

pca = PCA(n_components=3)
pca.fit(train_images_numpy)
ones_3pca = pca.transform(ones_numpy)
eights_3pca = pca.transform(eights_numpy)
#fours_3pca = pca.transform(fours_numpy)

fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

ax.scatter(eights_3pca[:,0], eights_3pca[:,1], eights_3pca[:,2],c='y', marker='o',alpha=0.1,lw = 0)
ax.scatter(ones_3pca[:,0], ones_3pca[:,1], ones_3pca[:,2],c='k', marker='o',alpha=0.998,lw = 0)
#ax.scatter(fours_3pca[:,0], fours_3pca[:,1], fours_3pca[:,2],c='g', marker='o',alpha=0.1,lw = 0)

plt.show()

# %% [markdown]
# ## 2.2 Digits

# %%
from matplotlib import pyplot as plt
from math import sqrt

def show_digit(digit_numpy):
    dimension = sqrt(len(digit_numpy))
    x = digit_numpy.reshape(dimension,dimension)
    plt.imshow(255-x, cmap='gray', interpolation='nearest', vmin=0, vmax=255)
    #plt.savefig('text.png')
    plt.show()

show_digit(eights_numpy[1,:])
# Out:
# C:\Program Files\Anaconda3\lib\site-packages\ipykernel\__main__.py:7: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future

# %% [markdown]
# ## 2.3 Class Distribution

# %%
dist = np.histogram(train_images['label'],bins=range(11))
plt.bar( range(10),dist[0],  color="b",align='center')
plt.show()

# %% [markdown]
#   # 3. Feature Engineering

# %% [markdown]
# ## 3.1 Feature Scaling

# %%
from sklearn.preprocessing import scale
train_scaled  = scale(train_images_numpy)
# Out:
# C:\Program Files\Anaconda3\lib\site-packages\sklearn\utils\validation.py:429: DataConversionWarning: Data with input dtype int64 was converted to float64 by the scale function.
#   warnings.warn(msg, _DataConversionWarning)

# %% [markdown]
# ## 3.1 Binary Features

# %%
train_binary = train_images_numpy > 0
train_binary
# Out:
# array([[False, False, False, ..., False, False, False],
#        [False, False, False, ..., False, False, False],
#        [False, False, False, ..., False, False, False],
#        ...,
#        [False, False, False, ..., False, False, False],
#        [False, False, False, ..., False, False, False],
#        [False, False, False, ..., False, False, False]], dtype=bool)

# %% [markdown]
# # 4. Classification

# %% [markdown]
# ## 4.1 KNN

# %%
# from sklearn.neighbors import KNeighborsClassifier
# from sklearn.cross_validation import cross_val_score

# knn= KNeighborsClassifier(n_neighbors=10,weights='distance',algorithm ='auto')
# scores = cross_val_score(knn, train_scaled, train_images['label'], cv=3)
# np.mean(scores)

# %% [markdown]
# ## 4.2 Multi Layer Perceptron

# %%
from sklearn.neural_network import MLPClassifier
mlpclf = MLPClassifier(hidden_layer_sizes=(50), 
                    verbose=1, tol=1e-4, random_state=1)
scores = cross_val_score(mlpclf, train_scaled, train_images['label'], cv=3)
np.mean(scores)
# Out:
# Iteration 1, loss = 0.57691126
# Iteration 2, loss = 0.22655203
# Iteration 3, loss = 0.16726437
# Iteration 4, loss = 0.13455679
# Iteration 5, loss = 0.11197062
# Iteration 6, loss = 0.09506815
# Iteration 7, loss = 0.08038377
# Iteration 8, loss = 0.06933883
# Iteration 9, loss = 0.05996018
# Iteration 10, loss = 0.05168984
# Iteration 11, loss = 0.04438915
# Iteration 12, loss = 0.03838386
# Iteration 13, loss = 0.03360140
# Iteration 14, loss = 0.02885683
# Iteration 15, loss = 0.02505570
# Iteration 16, loss = 0.02189640
# Iteration 17, loss = 0.01883963
# Iteration 18, loss = 0.01629088
# Iteration 19, loss = 0.01404059
# Iteration 20, loss = 0.01253863
# Iteration 21, loss = 0.01084679
# Iteration 22, loss = 0.00972947
# Iteration 23, loss = 0.00843733
# Iteration 24, loss = 0.00738058
# Iteration 25, loss = 0.00642030
# Iteration 26, loss = 0.00590107
# Iteration 27, loss = 0.00510846
# Iteration 28, loss = 0.00453992
# Iteration 29, loss = 0.00414685
# Iteration 30, loss = 0.00359077
# Iteration 31, loss = 0.00322155
# Iteration 32, loss = 0.00288733
# Iteration 33, loss = 0.00263113
# Iteration 34, loss = 0.00245945
# Iteration 35, loss = 0.00216711
# Iteration 36, loss = 0.00198525
# Iteration 37, loss = 0.00182110
# Iteration 38, loss = 0.00162012
# Iteration 39, loss = 0.00153283
# Iteration 40, loss = 0.00138424
# Iteration 41, loss = 0.00128189
# Iteration 42, loss = 0.00116873
# Iteration 43, loss = 0.00108903
# Iteration 44, loss = 0.00098860
# Iteration 45, loss = 0.00091967
# Iteration 46, loss = 0.00085228
# Iteration 47, loss = 0.00078483
# Training loss did not improve more than tol=0.000100 for two consecutive epochs. Stopping.
# Iteration 1, loss = 0.58719753
# Iteration 2, loss = 0.23432459
# Iteration 3, loss = 0.17060773
# Iteration 4, loss = 0.13631071
# Iteration 5, loss = 0.11241119
# Iteration 6, loss = 0.09944061
# Iteration 7, loss = 0.08121249
# Iteration 8, loss = 0.06987589
# Iteration 9, loss = 0.06125378
# Iteration 10, loss = 0.05254984
# Iteration 11, loss = 0.04611502
# Iteration 12, loss = 0.04015418
# Iteration 13, loss = 0.03507388
# Iteration 14, loss = 0.03081450
# Iteration 15, loss = 0.02698449
# Iteration 16, loss = 0.02344549
# Iteration 17, loss = 0.02042609
# Iteration 18, loss = 0.01786291
# Iteration 19, loss = 0.01588261
# Iteration 20, loss = 0.01371301
# Iteration 21, loss = 0.01223265
# Iteration 22, loss = 0.01074537
# Iteration 23, loss = 0.00932015
# Iteration 24, loss = 0.00823312
# Iteration 25, loss = 0.00706850
# Iteration 26, loss = 0.00679582
# Iteration 27, loss = 0.00571238
# Iteration 28, loss = 0.00499491
# Iteration 29, loss = 0.00458746
# Iteration 30, loss = 0.00400985
# Iteration 31, loss = 0.00352222
# Iteration 32, loss = 0.00329141
# Iteration 33, loss = 0.00288722
# Iteration 34, loss = 0.00263488
# Iteration 35, loss = 0.00239796
# Iteration 36, loss = 0.00217642
# Iteration 37, loss = 0.00200927
# Iteration 38, loss = 0.00182932
# Iteration 39, loss = 0.00164870
# Iteration 40, loss = 0.00151447
# Iteration 41, loss = 0.00138561
# Iteration 42, loss = 0.00127089
# Iteration 43, loss = 0.00120545
# Iteration 44, loss = 0.00108820
# Iteration 45, loss = 0.00100908
# Iteration 46, loss = 0.00931089
# Iteration 47, loss = 0.02646694
# Training loss did not improve more than tol=0.000100 for two consecutive epochs. Stopping.
# Iteration 1, loss = 0.59097852
# Iteration 2, loss = 0.23573832
# Iteration 3, loss = 0.17285077
# Iteration 4, loss = 0.13883765
# Iteration 5, loss = 0.11805511
# Iteration 6, loss = 0.09893794
# Iteration 7, loss = 0.08311036
# Iteration 8, loss = 0.07142428
# Iteration 9, loss = 0.06175909
# Iteration 10, loss = 0.05384837
# Iteration 11, loss = 0.04652768
# Iteration 12, loss = 0.04052657
# Iteration 13, loss = 0.03495509
# Iteration 14, loss = 0.03040834
# Iteration 15, loss = 0.02629680
# Iteration 16, loss = 0.02312424
# Iteration 17, loss = 0.01978013
# Iteration 18, loss = 0.01723539
# Iteration 19, loss = 0.01744764
# Iteration 20, loss = 0.01364322
# Iteration 21, loss = 0.01166521
# Iteration 22, loss = 0.00994967
# Iteration 23, loss = 0.00880382
# Iteration 24, loss = 0.02600509
# Iteration 25, loss = 0.00982162
# Iteration 26, loss = 0.00710408
# Iteration 27, loss = 0.00608168
# Iteration 28, loss = 0.00717704
# Iteration 29, loss = 0.00484688
# Iteration 30, loss = 0.00424516
# Iteration 31, loss = 0.00407865
# Iteration 32, loss = 0.00352980
# Iteration 33, loss = 0.00316200
# Iteration 34, loss = 0.00293579
# Iteration 35, loss = 0.00264069
# Iteration 36, loss = 0.00255061
# Iteration 37, loss = 0.00256891
# Iteration 38, loss = 0.00216069
# Iteration 39, loss = 0.00200042
# Iteration 40, loss = 0.00183907
# Iteration 41, loss = 0.00174024
# Iteration 42, loss = 0.00156342
# Iteration 43, loss = 0.00143195
# Iteration 44, loss = 0.00133224
# Iteration 45, loss = 0.00126260
# Iteration 46, loss = 0.00116526
# Training loss did not improve more than tol=0.000100 for two consecutive epochs. Stopping.
# 0.95807133503668196

# %% [markdown]
# ## 4.3 Ensemble Method

# %%
# from sklearn.ensemble import GradientBoostingClassifier 
# ensemble = GradientBoostingClassifier(learning_rate=0.1,verbose =1)
# scores = cross_val_score(ensemble, train_scaled, train_images['label'], cv=5)
# mean(scores)

# %% [markdown]
# ## 4.5 Deep Learning (SKFlow)

# %%
import tensorflow.contrib.learn as skflow
import tensorflow as tf
feature_columns = [tf.contrib.layers.real_valued_column("", dimension=4)]
classifier = skflow.DNNClassifier(feature_columns=feature_columns,hidden_units=[5, 7, 5], n_classes=10)
classifier.fit(train_scaled, train_images['label'])
score = metrics.accuracy_score(train_scaled, classifier.predict(train_scaled))
print("Accuracy: %f" % score)
tf.train.Saver(write_version=tf.train.SaverDef.V2)

# %% [markdown]
# ## 4.6 My own Multi Layer Perceptron

# %%
from importlib.machinery import SourceFileLoader
from sklearn import preprocessing

X = train_scaled
lb = preprocessing.LabelBinarizer()
Y= lb.fit_transform(train_images['label'])

borna = SourceFileLoader("MLP", "../My MLP Implementation/MLP.py").load_module()
sigmoid = borna.sigmoid
ml_batch= borna.bornaMLP([784,50,10],activations=10*[sigmoid],epocs=5,eta=.05,update='online')
ml_batch.fit(X,Y)
plt.plot(range(len(ml_batch.errors)), ml_batch.errors,'r')
plt.show()
print sum(np.array(labels) == train_images['label'])/Y.shape[0]
# Out:
# epoc-> 0
# epoc-> 1
# epoc-> 2
# epoc-> 3
# epoc-> 4
# epoc-> 5
# epoc-> 6
# epoc-> 7
# epoc-> 8
# epoc-> 9
# epoc-> 10

# %%
import random
scores=[]
n = 3
X=np.array([[1,2,3],[3,4,5],[5,6,7]])

all_indices = set(range(X.shape[0]))

oneth = i*X.shape[0]/n
for i in range(n):
    test_indices = set(random.sample(range(X.shape[0]),int(onenth)))
    train_indices = all_indices.difference(test_indices)
    print (test_indices,train_indices)
    test_X = X[list(test_indices)]
    test_Y = Y[list(test_indices)]
    train_X = X[list(train_indices)]
    train_Y = Y[list(train_indices)]
# Out:
# {1, 2} {0}
# {0, 1} {2}
# {0, 2} {1}

# %%
onenth
# Out:
# 2.0
